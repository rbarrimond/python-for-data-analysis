# %% [markdown]
# ## Bar Chart Configuration
#
# In this demo we will be using **Serie Configuration** i.e Options can be customized every time when data is added.
# Serie Configuration can be applied to any graph while adding to the data.
#
# Here, Bar graph is used to demonstrate the *configuration*

# %%
import pygal
from IPython.display import display, HTML

# %% [markdown]
# Method to display the **interactive graph** in Jupyter notebook. The method defined below takes in the **html code** and the **rendered chart**, inserts the chart into html code to display the chart with interactive graphics.

# %%
html_skeleton = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" 
          src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
  </script>
  <script type="text/javascript" 
          src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
  </script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

def display_chart(chart):
    rendered_chart = chart.render(is_unicode=True)
    plot_html = html_skeleton.format(rendered_chart=rendered_chart)
    display(HTML(plot_html))

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True)

# %%
bar_chart.title = "Pet Population By Animal Per 100 households"

# %%
display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-4ed1d1b8-eb30-429e-b894-282804450cb1" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-4ed1d1b8-eb30-429e-b894-282804450cb1{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-4ed1d1b8-eb30-429e-b894-282804450cb1{background-color:rgba(249,249,249,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 path,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 rect,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .graph{fill:rgba(0,0,0,.87)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 text.no_data{fill:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .title{fill:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis .line{stroke:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis text.major{fill:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.y .guides:hover .guide.line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .line-graph .axis.x .guides:hover .guide.line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .ci{stroke:rgba(0,0,0,.87)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .reactive.active,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .ci .reactive.active{stroke-width:1.5}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .series text{fill:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip .value{font-size:1.5em}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .bound{font-size:.5em}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}
# #chart-4ed1d1b8-eb30-429e-b894-282804450cb1 text.no_data{text-anchor:middle}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .guide.line{fill:none}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .centered{text-anchor:middle}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .title{text-anchor:middle}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .legends .legend text{fill-opacity:1}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.x text{text-anchor:middle}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.y text{text-anchor:end}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.y text[transform].backwards{text-anchor:start}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.y2 text{text-anchor:start}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.y2 text[transform].backwards{text-anchor:end}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .horizontal .axis.y .guide.line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .horizontal .axis.y2 .guide.line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .vertical .axis.x .guide.line{opacity:0}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .horizontal .axis.always_show .guide.line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.y .guides:hover .guide.line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.y2 .guides:hover .guide.line,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis.x .guides:hover .guide.line{opacity:1}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .axis .guides:hover text{opacity:1}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .nofill{fill:none}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .subtle-fill{fill-opacity:.2}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .dot.active{stroke-width:5px}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .dot.negative{fill:transparent}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 text,#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 tspan{stroke:none !important}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .series text.active{opacity:1}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip rect{fill-opacity:.95;stroke-width:.5}#chart-4ed1d1b8-eb30-429e-b894-282804450cb1 .tooltip text{fill-opacity:1}#chart-4ed1d1

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True, 
                      no_data_text = 'Data Missing :(')

# %%
bar_chart.title = "Pet Population By Animal Per 100 households"
display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce{background-color:rgba(249,249,249,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce path,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce rect,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .graph{fill:rgba(0,0,0,.87)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce text.no_data{fill:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .title{fill:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .legends .legend text{fill:rgba(0,0,0,.87)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis .line{stroke:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis text.major{fill:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.y .guides:hover .guide.line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .line-graph .axis.x .guides:hover .guide.line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .stackedline-graph .axis.x .guides:hover .guide.line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .ci{stroke:rgba(0,0,0,.87)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .reactive.active,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .ci .reactive.active{stroke-width:1.5}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .series text{fill:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip .label{fill:rgba(0,0,0,.87)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip .label{fill:rgba(0,0,0,.87)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip .value{font-size:1.5em}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .bound{font-size:.5em}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}
# #chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce text.no_data{text-anchor:middle}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .guide.line{fill:none}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .centered{text-anchor:middle}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .title{text-anchor:middle}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .legends .legend text{fill-opacity:1}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.x text{text-anchor:middle}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.x:not(.web) text[transform]{text-anchor:start}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.y text{text-anchor:end}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.y text[transform].backwards{text-anchor:start}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.y2 text{text-anchor:start}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.y2 text[transform].backwards{text-anchor:end}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .horizontal .axis.y .guide.line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .horizontal .axis.y2 .guide.line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .vertical .axis.x .guide.line{opacity:0}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .horizontal .axis.always_show .guide.line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.y .guides:hover .guide.line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.y2 .guides:hover .guide.line,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis.x .guides:hover .guide.line{opacity:1}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .axis .guides:hover text{opacity:1}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .nofill{fill:none}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .subtle-fill{fill-opacity:.2}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .dot.active{stroke-width:5px}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .dot.negative{fill:transparent}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce text,#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce tspan{stroke:none !important}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .series text.active{opacity:1}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip rect{fill-opacity:.95;stroke-width:.5}#chart-53b5f17b-572a-4a7c-b3a2-a3e5b4070fce .tooltip text{fill-opacity:1}#chart-53b5f1

# %% [markdown]
# Initialize the bar chart object and pass in the parameter **print_vales=True** which will print the values on the bar chart.

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True,
                      no_data_text = 'Data Missing :(',
                      print_values=True)

bar_chart.title = "Pet Population By Animal Per 100 households"

# %% [markdown]
# Add in the data to the chart and notice that we have passed in the parameter **rounded_bars** which will **round the edges of the bars** Then pass in the chart to **display_chart** method to display the interactive chart.

# %%
bar_chart.add('Dogs', 41, 
              rounded_bars = 10)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{background-color:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 path,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 rect,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .line-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive.active,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci .reactive.active{stroke-width:1.5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .series text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .value{font-size:1.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .bound{font-size:.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay .color-0 text{fill:black}
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .guide.line{fill:none}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .centered{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill-opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x text{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text[transform].backwards{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y2 .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.x .guide.line{opacity:0}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.always_show .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x .guides:hover .guide.line{opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .nofill{fill:none}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .subtle-fill{fill-opacity:.2}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .dot.active{stroke-width:5px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .dot.negative{fill:transparent}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 tspan{stroke:none !important}#chart-ccfbf244-1cfc-40b

# %% [markdown]
# We can pass in the individual **formatter** to format the individual bar.

# %%
bar_chart.add('Cats', 20, 
              rounded_bars = 50, 
              formatter = lambda x: '%s Cats' % x)
display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{background-color:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 path,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 rect,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .line-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive.active,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci .reactive.active{stroke-width:1.5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .series text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .value{font-size:1.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .bound{font-size:.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay .color-0 text{fill:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay .color-1 text{fill:black}
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .guide.line{fill:none}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .centered{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill-opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x text{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text[transform].backwards{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y2 .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.x .guide.line{opacity:0}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.always_show .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x .guides:hover .guide.line{opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .nofill{fill:none}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .subtle-fill{fill-opacity:.2}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .dot.active{stroke-widt

# %% [markdown]
# You can pass in the style like the **fill**, **stroke** color and **stroke-width**

# %%
bar_chart.add('Birds', 
              [{'value': 12, 
                'style': 'fill: green; stroke: black; stroke-width: 4'}])

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{background-color:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 path,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 rect,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .line-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive.active,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci .reactive.active{stroke-width:1.5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .series text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .value{font-size:1.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .bound{font-size:.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-2,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay .color-0 text{fill:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay .color-1 text{fill:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay .color-2 text{fill ...
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .guide.line{fill:none}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .centered{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill-opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x text{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text[transform].backwards{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y2 .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.x .guide.line{opacity:0}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.always_show .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x .guides:hover .guide.line{opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .nofill{fill:none}#chart-ccfb

# %% [markdown]
# Embed a **link** in the bar, when you hover over the bar plotted. You can define the link using **xlink** field notice, the values passed in a dictionary inside a list.
#
# When you hover over the **horse** you can see the link embedded. Link takes you to adopt a hourse to bluecross pet website.

# %%
bar_chart.add('Horses', 
              [{'value': 7,
                'xlink': 'https://www.bluecross.org.uk/rehome/horse'}])

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{background-color:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 path,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 rect,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .line-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive.active,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci .reactive.active{stroke-width:1.5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .series text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .value{font-size:1.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .bound{font-size:.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-2,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-3,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay .color-0 text{fill:black}#chart-ccfbf244 ...
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .guide.line{fill:none}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .centered{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill-opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x text{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text[transform].backwards{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y2 .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.x .guide.line{opacity:0}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.always_show .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 .guides:hover .guide.line,#chart-ccfbf2

# %% [markdown]
# You can change the **color** of the bar using **color** field passed in dictionary. Here we are changing the color of the **Exotic pets** to **Maroon**, just to distinguish between other bars regardless of the legend.

# %%
bar_chart.add('Exotic Pets', 
              [{'value': 2, 
                'color': 'maroon'}])

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{background-color:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 path,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 rect,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .line-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive.active,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci .reactive.active{stroke-width:1.5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .series text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .value{font-size:1.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .bound{font-size:.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-2,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-3,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-4,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 . ...
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .guide.line{fill:none}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .centered{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill-opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x text{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text[transform].backwards{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y2 .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .vertical .axis.x .guide.line{opacity:0}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.always_show .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ver

# %% [markdown]
# You can add a link to the **legend of bar**. Here, **we are adding a link to bluecross pet website to adopt a pet.**

# %%
bar_chart.add({'title': 'No Pets',
               'xlink': {'href': 'https://www.bluecross.org.uk/rehome-pet'}
              }, 
              18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59{background-color:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 path,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 rect,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .graph{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis text.major{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .line-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci{stroke:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .reactive.active,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .ci .reactive.active{stroke-width:1.5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .series text{fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .tooltip .value{font-size:1.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .bound{font-size:.5em}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-2,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-3,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .color-4,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 . ...
# #chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 text.no_data{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .guide.line{fill:none}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .centered{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .title{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .legends .legend text{fill-opacity:1}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x text{text-anchor:middle}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y text[transform].backwards{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text{text-anchor:start}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis.y2 text[transform].backwards{text-anchor:end}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y .guide.line,#chart-ccfbf244-1cfc-40b1-8d1e-0d2bde6c4d59 .horizontal .axis.y2 .gu

# %%
from pygal.style import DarkStyle

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True)

# %%
bar_chart.style = DarkStyle

# %%
bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73{background-color:black}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 path,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 line,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 rect,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .graph &gt; .background{fill:black}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .plot &gt; .background{fill:#111}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .graph{fill:#999}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 text.no_data{fill:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .title{fill:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .legends .legend text{fill:#999}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .legends .legend:hover text{fill:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis .line{stroke:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis .guide.line{stroke:#555}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis .major.line{stroke:#999}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis text.major{fill:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis.y .guides:hover .guide.line,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .line-graph .axis.x .guides:hover .guide.line,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis .guides:hover text{fill:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .reactive{fill-opacity:.8;stroke-opacity:.8;stroke-width:1}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .ci{stroke:#999}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .reactive.active,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .ci .reactive.active{stroke-width:1.5}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .series text{fill:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .tooltip .label{fill:#999}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .tooltip .label{fill:#999}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .tooltip .legend{font-size:.8em;fill:#555}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .tooltip .x_label{font-size:.6em;fill:#eee}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .tooltip .value{font-size:1.5em}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .bound{font-size:.5em}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .max-value{font-size:.75em;fill:#555}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .map-element{fill:#111;stroke:#555 !important}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-0,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-0 a:visited{stroke:#ff5995;fill:#ff5995}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-1,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-1 a:visited{stroke:#b6e354;fill:#b6e354}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-2,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-2 a:visited{stroke:#feed6c;fill:#feed6c}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-3,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-3 a:visited{stroke:#8cedff;fill:#8cedff}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-4,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-4 a:visited{stroke:#9e6ffe;fill:#9e6ffe}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-5,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .color-5 a:visited{stroke:#899ca1;fill:#899ca1}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .text-overlay .color-0 text{fill:black} ...
# #chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 text.no_data{text-anchor:middle}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .guide.line{fill:none}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .centered{text-anchor:middle}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .title{text-anchor:middle}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .legends .legend text{fill-opacity:1}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis.x text{text-anchor:middle}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis.y text{text-anchor:end}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis.y text[transform].backwards{text-anchor:start}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis.y2 text{text-anchor:start}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis.y2 text[transform].backwards{text-anchor:end}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .horizontal .axis.y .guide.line,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .horizontal .axis.y2 .guide.line,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .vertical .axis.x .guide.line{opacity:0}#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .horizontal .axis.always_show .guide.line,#chart-3e23a789-0b2f-4d24-a3e2-992eeaac2f73 .vertical .axis.always_show .guide.line{opacity:1

# %% [markdown]
# #### Parametric Styles

# %%
from pygal.style import DarkenStyle

# %%
darken_style = DarkenStyle('#75FFFD')

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True, 
                      style = darken_style)

# %%
bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a{background-color:rgba(249,249,249,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a path,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a rect,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .graph{fill:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a text.no_data{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .title{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .legends .legend text{fill:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .line{stroke:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis text.major{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y .guides:hover .guide.line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .line-graph .axis.x .guides:hover .guide.line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .stackedline-graph .axis.x .guides:hover .guide.line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .ci{stroke:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .reactive.active,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .ci .reactive.active{stroke-width:1.5}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .series text{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .value{font-size:1.5em}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .bound{font-size:.5em}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-0,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-0 a:visited{stroke:#75fffd;fill:#75fffd}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-1,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-1 a:visited{stroke:#59fffd;fill:#59fffd}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-2,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-2 a:visited{stroke:#3cfffc;fill:#3cfffc}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-3,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-3 a:visited{stroke:#20fffc;fill:#20fffc}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-4,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a . ...
# #chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a text.no_data{text-anchor:middle}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .guide.line{fill:none}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .centered{text-anchor:middle}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .title{text-anchor:middle}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .legends .legend text{fill-opacity:1}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.x text{text-anchor:middle}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.x:not(.web) text[transform]{text-anchor:start}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y text{text-anchor:end}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y text[transform].backwards{text-anchor:start}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y2 text{text-anchor:start}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y2 text[transform].backwards{text-anchor:end}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .horizontal .axis.y .guide.line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .horizontal .axis.y2 .gu

# %%
bar_chart.style = DarkenStyle('#75FFFD', 
                              step = 5)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a{background-color:rgba(249,249,249,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a path,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a rect,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .graph{fill:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a text.no_data{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .title{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .legends .legend text{fill:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .line{stroke:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis text.major{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y .guides:hover .guide.line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .line-graph .axis.x .guides:hover .guide.line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .stackedline-graph .axis.x .guides:hover .guide.line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .ci{stroke:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .reactive.active,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .ci .reactive.active{stroke-width:1.5}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .series text{fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .tooltip .value{font-size:1.5em}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .bound{font-size:.5em}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-0,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-0 a:visited{stroke:#75fffd;fill:#75fffd}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-1,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-1 a:visited{stroke:#35fffc;fill:#35fffc}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-2,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-2 a:visited{stroke:#00f4f1;fill:#00f4f1}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-3,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-3 a:visited{stroke:#00b5b2;fill:#00b5b2}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .color-4,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a . ...
# #chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a text.no_data{text-anchor:middle}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .guide.line{fill:none}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .centered{text-anchor:middle}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .title{text-anchor:middle}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .legends .legend text{fill-opacity:1}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.x text{text-anchor:middle}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.x:not(.web) text[transform]{text-anchor:start}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y text{text-anchor:end}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y text[transform].backwards{text-anchor:start}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y2 text{text-anchor:start}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis.y2 text[transform].backwards{text-anchor:end}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .horizontal .axis.y .guide.line,#chart-4926dd56-b012-48a2-82ac-fdfa0ce9f11a .horizontal .axis.y2 .gu

# %%
from pygal.style import Style

# %%
custom_style = Style(background='#ECF2F2',
                     plot_background='transparent',
                     opacity='.6',
                     transition='400ms ease-in',
                     legend_font_family = 'arial',
                     legend_font_size = 12,
                     colors=('red', '#8299F7', 
                             '#ED8223', 'purple', 
                             '#E89B53', 'deeppink'))

# %%
bar_chart = pygal.Bar(width = 640,
                      height = 360,
                      explicit_size = True, 
                      style = custom_style)

# %%
bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .legends .legend text{font-family:arial;font-size:12px}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f{background-color:#ECF2F2}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f path,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f line,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f rect,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f circle{-webkit-transition:400ms ease-in;-moz-transition:400ms ease-in;transition:400ms ease-in}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .graph &gt; .background{fill:#ECF2F2}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .plot &gt; .background{fill:transparent}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .graph{fill:rgba(0,0,0,.87)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f text.no_data{fill:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .title{fill:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .legends .legend text{fill:rgba(0,0,0,.87)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis .line{stroke:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis text.major{fill:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis.y .guides:hover .guide.line,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .line-graph .axis.x .guides:hover .guide.line,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .stackedline-graph .axis.x .guides:hover .guide.line,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .reactive{fill-opacity:.6;stroke-opacity:.8;stroke-width:1}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .ci{stroke:rgba(0,0,0,.87)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .reactive.active,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .ci .reactive.active{stroke-width:1.5}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .series text{fill:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .tooltip rect{fill:transparent;stroke:rgba(0,0,0,1);-webkit-transition:opacity 400ms ease-in;-moz-transition:opacity 400ms ease-in;transition:opacity 400ms ease-in}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .tooltip .label{fill:rgba(0,0,0,.87)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .tooltip .label{fill:rgba(0,0,0,.87)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .tooltip .value{font-size:1.5em}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .bound{font-size:.5em}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .map-element{fill:transparent;stroke:rgba(0,0,0,.54) !important}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-0,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-0 a:visited{stroke:red;fill:red}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-1,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-1 a:visited{stroke:#8299F7;fill:#8299F7}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-2,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-2 a:visited{stroke:#ED8223;fill:#ED8223}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-3,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-3 a:visited{stroke:purple;fill:purple}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-4,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .color-4 a: ...
# #chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f text.no_data{text-anchor:middle}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .guide.line{fill:none}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .centered{text-anchor:middle}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .title{text-anchor:middle}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .legends .legend text{fill-opacity:1}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis.x text{text-anchor:middle}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis.x:not(.web) text[transform]{text-anchor:start}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis.y text{text-anchor:end}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis.y text[transform].backwards{text-anchor:start}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis.y2 text{text-anchor:start}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis.y2 text[transform].backwards{text-anchor:end}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .horizontal .axis.y .guide.line,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f .horizontal .axis.y2 .guide.line,#chart-5bdf6929-5e24-4f6b-91ab-64e5638be48f

# %%
from pygal import Config

# %%
custom_config = Config(width = 640,
                       height = 360,
                       explicit_size = True, 
                       style = custom_style)

# %%
bar_chart = pygal.Bar(config = custom_config)

# %%
bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .legends .legend text{font-family:arial;font-size:12px}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e{background-color:#ECF2F2}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e path,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e line,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e rect,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e circle{-webkit-transition:400ms ease-in;-moz-transition:400ms ease-in;transition:400ms ease-in}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .graph &gt; .background{fill:#ECF2F2}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .plot &gt; .background{fill:transparent}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .graph{fill:rgba(0,0,0,.87)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e text.no_data{fill:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .title{fill:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .legends .legend text{fill:rgba(0,0,0,.87)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis .line{stroke:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis text.major{fill:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis.y .guides:hover .guide.line,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .line-graph .axis.x .guides:hover .guide.line,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .stackedline-graph .axis.x .guides:hover .guide.line,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .reactive{fill-opacity:.6;stroke-opacity:.8;stroke-width:1}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .ci{stroke:rgba(0,0,0,.87)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .reactive.active,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .ci .reactive.active{stroke-width:1.5}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .series text{fill:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .tooltip rect{fill:transparent;stroke:rgba(0,0,0,1);-webkit-transition:opacity 400ms ease-in;-moz-transition:opacity 400ms ease-in;transition:opacity 400ms ease-in}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .tooltip .label{fill:rgba(0,0,0,.87)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .tooltip .label{fill:rgba(0,0,0,.87)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .tooltip .value{font-size:1.5em}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .bound{font-size:.5em}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .map-element{fill:transparent;stroke:rgba(0,0,0,.54) !important}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-0,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-0 a:visited{stroke:red;fill:red}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-1,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-1 a:visited{stroke:#8299F7;fill:#8299F7}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-2,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-2 a:visited{stroke:#ED8223;fill:#ED8223}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-3,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-3 a:visited{stroke:purple;fill:purple}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-4,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .color-4 a: ...
# #chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e text.no_data{text-anchor:middle}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .guide.line{fill:none}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .centered{text-anchor:middle}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .title{text-anchor:middle}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .legends .legend text{fill-opacity:1}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis.x text{text-anchor:middle}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis.x:not(.web) text[transform]{text-anchor:start}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis.y text{text-anchor:end}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis.y text[transform].backwards{text-anchor:start}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis.y2 text{text-anchor:start}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis.y2 text[transform].backwards{text-anchor:end}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .horizontal .axis.y .guide.line,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e .horizontal .axis.y2 .guide.line,#chart-7bc379ce-75f5-425e-b86c-fe86278f0f0e

# %%
custom_config = Config(width = 640,
                       height = 360,
                       explicit_size = True, 
                       style = custom_style, 
                       spacing = 50, 
                       margin_bottom = 100)

# %%
bar_chart = pygal.Bar(config = custom_config)

bar_chart.add('Dogs', 41)
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

display_chart(bar_chart)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript"
#           src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js">
#   </script>
#   <script type="text/javascript"
#           src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"">
#   </script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-1ca5d293-110c-420c-89ed-f4ef24a316c6" class="pygal-chart" viewBox="0 0 640 360" width="640" height="360"><!--Generated with pygal 3.0.0 (lxml) ©Kozea 2012-2016 on 2023-11-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .legends .legend text{font-family:arial;font-size:12px}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-1ca5d293-110c-420c-89ed-f4ef24a316c6{background-color:#ECF2F2}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 path,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 line,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 rect,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 circle{-webkit-transition:400ms ease-in;-moz-transition:400ms ease-in;transition:400ms ease-in}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .graph &gt; .background{fill:#ECF2F2}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .plot &gt; .background{fill:transparent}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .graph{fill:rgba(0,0,0,.87)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 text.no_data{fill:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .title{fill:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis .line{stroke:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis text.major{fill:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis.y .guides:hover .guide.line,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .line-graph .axis.x .guides:hover .guide.line,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .reactive{fill-opacity:.6;stroke-opacity:.8;stroke-width:1}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .ci{stroke:rgba(0,0,0,.87)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .reactive.active,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .ci .reactive.active{stroke-width:1.5}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .series text{fill:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .tooltip rect{fill:transparent;stroke:rgba(0,0,0,1);-webkit-transition:opacity 400ms ease-in;-moz-transition:opacity 400ms ease-in;transition:opacity 400ms ease-in}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .tooltip .value{font-size:1.5em}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .bound{font-size:.5em}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .map-element{fill:transparent;stroke:rgba(0,0,0,.54) !important}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-0,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-0 a:visited{stroke:red;fill:red}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-1,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-1 a:visited{stroke:#8299F7;fill:#8299F7}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-2,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-2 a:visited{stroke:#ED8223;fill:#ED8223}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-3,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-3 a:visited{stroke:purple;fill:purple}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-4,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .color-4 a: ...
# #chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 text.no_data{text-anchor:middle}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .guide.line{fill:none}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .centered{text-anchor:middle}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .title{text-anchor:middle}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .legends .legend text{fill-opacity:1}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis.x text{text-anchor:middle}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis.y text{text-anchor:end}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis.y text[transform].backwards{text-anchor:start}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis.y2 text{text-anchor:start}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis.y2 text[transform].backwards{text-anchor:end}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .horizontal .axis.y .guide.line,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6 .horizontal .axis.y2 .guide.line,#chart-1ca5d293-110c-420c-89ed-f4ef24a316c6
