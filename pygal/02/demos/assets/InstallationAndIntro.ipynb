# %% [markdown]
# ### Installation
#
# Install the pyagal package using pip install and use in-memory values to plot the bar graph. Here, the imaginary Pet survey data is used.

# %% [markdown]
# **Optional Installation command **
#
# brew install cairo
#
# Add these two lines to the .bash_profile file:
#
# export LC_ALL=en_US.UTF-8
#
# export LANG=en_US.UTF-8

# %%
# %pip install pygal
# Out:
# Requirement already satisfied: pygal in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ** Install another package to display the charts on jupyter notebook that processes the svg file to png file. **

# %%
# %pip install cairosvg
# Out:
# Requirement already satisfied: cairosvg in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (2.7.1)
# Requirement already satisfied: cairocffi in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (from cairosvg) (1.6.1)
# Requirement already satisfied: cssselect2 in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (from cairosvg) (0.7.0)
# Requirement already satisfied: defusedxml in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (from cairosvg) (0.7.1)
# Requirement already satisfied: pillow in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (from cairosvg) (10.1.0)
# Requirement already satisfied: tinycss2 in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (from cairosvg) (1.2.1)
# Requirement already satisfied: cffi>=1.1.0 in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (from cairocffi->cairosvg) (1.16.0)
# Requirement already satisfied: webencodings in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (from cssselect2->cairosvg) (0.5.1)
# Requirement already satisfied: pycparser in /home/rbarrimo/developer/python-for-data-analysis/.venv/lib/python3.11/site-packages (from cffi>=1.1.0->cairocffi->cairosvg) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Let's import the pygal and initialize the Pygal object.

# %%
import pygal
import os
import webbrowser

# %%
bar_chart = pygal.Bar()

# %% [markdown]
# Take some data to show the bar. Figures are imaginary

# %%
bar_chart.title = "Pet Population By Animal Per 100 households"

# %% [markdown]
# Add the data to the bar chart.

# %%
bar_chart.add('Dogs', 41)

# %%
bar_chart = pygal.Bar(height = 360, 
                      width = 640, 
                      explicit_size=True)

# %%
bar_chart.title = "Pet Population By Animal Per 100 households"

bar_chart.add('Dogs', 41)

# %% [markdown]
# Add the data to the chart at one go.

# %%
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)

# %%
bar_chart.render_to_file('pet_bar_chart.svg')

# %% [markdown]
# **Import the os module and get the absolute path to be able to open in the browser.**

# %%
def open_in_browser(file_to_open):    
    file_path = os.path.realpath(file_to_open)
    file_url = 'file://' + file_path
    # browser = webbrowser.get('chrome')
    browser = webbrowser.get()
    browser.open(file_url)

# %%
open_in_browser('pet_bar_chart.svg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/rbarrimo/developer/python-for-data-analysis/pygal/02/demos/assets/InstallationAndIntro.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/rbarrimo/developer/python-for-data-analysis/pygal/02/demos/assets/InstallationAndIntro.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> open_in_browser('pet_bar_chart.svg')
#
# /home/rbarrimo/developer/python-for-data-analysis/pygal/02/demos/assets/InstallationAndIntro.ipynb Cell 20 line 6
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/rbarrimo/developer/python-for-data-analysis/pygal/02/demos/assets/InstallationAndIntro.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> file_url = 'file://' + file_path
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/rbarrimo/developer/python-for-data-analysis/pygal/02/demos/assets/InstallationAndIntro.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # browser = webbrowser.get('chrome')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/rbarrimo/developer/python-for-data-analysis/pygal/02/demos/assets/InstallationAndIntro.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> # browser = webbrowser.get('windows-default')
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/rbarrimo/developer/python-for-data-analysis/pygal/02/demos/assets/InstallationAndIntro.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> browser.open(file_url)
#
# NameError: name 'browser' is not defined

# %% [markdown]
# ### Horizontal Bar
# The Bar chart can be flipped as Horizontal BarChart.

# %%
horizontal_bar = pygal.HorizontalBar(height = 360, 
                                     width = 640, 
                                     explicit_size=True)

horizontal_bar.title = "Pet Population By Animal Per 100 households"

# %%
horizontal_bar.add('Dogs',41)
horizontal_bar.add('Bird',12)
horizontal_bar.add('Horses', 7)
horizontal_bar.add('Exotic Pets',2)
horizontal_bar.add('No Pets',18)

# %%
horizontal_bar.render_to_file('pet_horizontal_bar_chart.svg')

# %%
open_in_browser('pet_horizontal_bar_chart.svg')
